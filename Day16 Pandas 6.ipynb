# %%
import pandas as pd

# %%
data2=pd.read_excel(r"D:\Minskole Batch\Python\input data.xlsx")

# %%
data3=data2.copy()

# %%
# Create new column in data3 "Total Marks"
data3["Total Marks"]=data3['English']+ data3['Physics']+ data3['Chemistry']+data3['Mathematics']

# %%
data3.head(2)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0      Aarav     Patil       85       78         90           92          345
# 1     Vihaan  Deshmukh       88       81         85           89          343

# %%
data3.sort_values(by="Last Name",ascending=True)
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 64        Jay       Bhagat       90       77         65           88
# 41       Jaya       Bhagat       92       88         76           89
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 9     Samarth       Shinde       89       79         87           88
# 17      Rohan  Suryavanshi       78       82         90           86
# 7       Rohan  Suryavanshi       78       82         90           86
# 24      Tejas     Waghmare       85       82         90           85
# 47      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 64          320
# 41          345
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data3.sort_values(by="Last Name",ascending=True,inplace=True)

# %%
data3
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 64        Jay       Bhagat       90       77         65           88
# 41       Jaya       Bhagat       92       88         76           89
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 9     Samarth       Shinde       89       79         87           88
# 17      Rohan  Suryavanshi       78       82         90           86
# 7       Rohan  Suryavanshi       78       82         90           86
# 24      Tejas     Waghmare       85       82         90           85
# 47      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 64          320
# 41          345
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data3.sort_values(by=["Last Name","Total Marks"],ascending=[True,False])
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 9     Samarth       Shinde       89       79         87           88
# 17      Rohan  Suryavanshi       78       82         90           86
# 7       Rohan  Suryavanshi       78       82         90           86
# 24      Tejas     Waghmare       85       82         90           85
# 47      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 41          345
# 64          320
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data3.columns
# Out:
# Index(['First Name', 'Last Name', 'English', 'Physics', 'Chemistry',
#        'Mathematics', 'Total Marks'],
#       dtype='object')

# %%
data3.sort_values(by=["Total Marks","First Name"],ascending=[False,True])
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 35      Sneha   Gokhale       88       84         90           86          348
# 58      Sneha   Gokhale       88       84         90           86          348
# 56      Aarvi  Bhandari       90       81         85           91          347
# 33      Aarvi  Bhandari       90       81         85           91          347
# 30      Aditi    Rajput       90       88         82           87          347
# ..        ...       ...      ...      ...        ...          ...          ...
# 14    Reyansh     Joshi       82       80         84           85          331
# 4     Reyansh     Joshi       82       80         84           85          331
# 50      Tanvi    Ingale       78       77         83           92          330
# 27      Tanvi    Ingale       78       77         83           92          330
# 64        Jay    Bhagat       90       77         65           88          320
#
# [65 rows x 7 columns]

# %% [markdown]
# ### Duplicate

# %%
data2[data2.duplicated()]
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics
# 10      Aarav        Patil       85       78         90           92
# 11     Vihaan     Deshmukh       88       81         85           89
# 12      Ayaan       Jadhav       90       75         88           84
# 13      Arjun         More       76       89         91           78
# 14    Reyansh        Joshi       82       80         84           85
# 15     Vivaan         Nair       87       83         79           90
# 16     Aditya        Pawar       92       88         76           91
# 17      Rohan  Suryavanshi       78       82         90           86
# 18      Krish      Bhosale       80       85         83           89
# 19    Samarth       Shinde       89       79         87           88
# 43       Riya     Kulkarni       91       84         78           87
# 44      Anaya      Gawande       84       90         82           88
# 45       Isha       Kamble       79       76         89           92
# ...

# %%
data3=data2.drop_duplicates()

# %%
data3[data3.duplicated()]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics, Chemistry, Mathematics]
# Index: []

# %%
data2.drop_duplicates(inplace=True)

# %%
data2[data2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics, Chemistry, Mathematics]
# Index: []

# %%
data4=pd.read_excel(r"D:\Minskole Batch\Python\Duplicated.xlsx")

# %%
data4
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1       Aarav     Patil       85       78         90           92
# 2       Aarav     Patil       85       78         92           92
# 3       Aarav     Patil       85       78         91           92
# 4       Aarav     Patil       85       78         98           92
# ..        ...       ...      ...      ...        ...          ...
# 63      Tejas  Waghmare       85       82         90           85
# 64     Vihaan  Deshmukh       88       81         85           89
# 65     Vihaan  Deshmukh       88       81         85           89
# 66     Vivaan      Nair       87       83         79           90
# 67     Vivaan      Nair       87       83         79           90
#
# [68 rows x 6 columns]

# %%
data5=pd.read_excel(r"D:\Minskole Batch\Python\Duplicated.xlsx",sheet_name="S2")

# %%
data5
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1      Aarav     Patil       85       78         90           92
# 2      Aarav     Patil       85       78         92           92
# 3      Aarav     Patil       85       78         91           92
# 4      Aarav     Patil       85       78         98           92
# 5      Aarvi  Bhandari       90       81         85           91
# 6      Aarvi  Bhandari       90       81         85           92

# %%
data5[data5.duplicated()]
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 1      Aarav     Patil       85       78         90           92

# %%
data5[data5.duplicated(subset=["First Name","Last Name","English","Physics","Chemistry","Mathematics"])]
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 1      Aarav     Patil       85       78         90           92

# %%
data5[data5.duplicated(subset=["First Name","Last Name"])]
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 1      Aarav     Patil       85       78         90           92
# 2      Aarav     Patil       85       78         92           92
# 3      Aarav     Patil       85       78         91           92
# 4      Aarav     Patil       85       78         98           92
# 6      Aarvi  Bhandari       90       81         85           92

# %%
data5
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1      Aarav     Patil       85       78         90           92
# 2      Aarav     Patil       85       78         92           92
# 3      Aarav     Patil       85       78         91           92
# 4      Aarav     Patil       85       78         98           92
# 5      Aarvi  Bhandari       90       81         85           91
# 6      Aarvi  Bhandari       90       81         85           92

# %%
data5[data5.duplicated(subset=["First Name","Last Name","Chemistry"])]
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 1      Aarav     Patil       85       78         90           92
# 6      Aarvi  Bhandari       90       81         85           92

# %%
data5[data5.duplicated(subset=["First Name","Last Name","Mathematics"])]
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 1      Aarav     Patil       85       78         90           92
# 2      Aarav     Patil       85       78         92           92
# 3      Aarav     Patil       85       78         91           92
# 4      Aarav     Patil       85       78         98           92

# %%
data5.drop_duplicates(inplace=True)

# %%
data5[data5.duplicated()]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics, Chemistry, Mathematics]
# Index: []

# %%
data5.drop_duplicates(subset=["First Name","Last Name","Chemistry"],inplace=True)

# %%
data5
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 2      Aarav     Patil       85       78         92           92
# 3      Aarav     Patil       85       78         91           92
# 4      Aarav     Patil       85       78         98           92
# 5      Aarvi  Bhandari       90       81         85           91

# %%
data5[data5.duplicated(subset=["First Name","Last Name","Chemistry"])]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics, Chemistry, Mathematics]
# Index: []
