# %%
### Apply: self defined function on dataframe

# %%
# Syntax
# data_frame_name.apply(Self-Defined_Function,axis=0/1)
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks  Percentage Grade
# 0           345       86.25    A+
# 1           343       85.75    A+
# 2           337       84.25    A+
# ...

# %% [raw]
# import pandas as pd

# %%
data=pd.read_excel(r"D:\Minskole Batch\Python\Input data.xlsx")

# %%
data.head()
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
# 2      Ayaan    Jadhav       90       75         88           84
# 3      Arjun      More       76       89         91           78
# 4    Reyansh     Joshi       82       80         84           85

# %%
# # Self defined function
# 1) Calculate total marks for each student
# 2) Calculate  percentage for each student
# 3) Give Grade according to marks 
# Above 90% Grade "O"
# Above 80% Grade "A+"
# Above 70% Grade "A"
# Above 60% Grade "B+"
# Above 50% Grade "B"
# Above 40% Grade "C+"
# Above 35% Grade "C"
# Otherwise Grade "F"

# %%
def Calculate_Result(data):
    data["Total Marks"]=data["English"]+data["Physics"]+data["Chemistry"]+data["Mathematics"]
    data["Percentage"]=(data["Total Marks"]/400)*100
    if data["Percentage"]>90:
        data["Grade"]="O"
    elif data["Percentage"]>80:
        data["Grade"]="A+"
    elif data["Percentage"]>70:
        data["Grade"]="A"        
    elif data["Percentage"]>60:
        data["Grade"]="B+"        
    elif data["Percentage"]>50:
        data["Grade"]="B"         
    elif data["Percentage"]>40:
        data["Grade"]="C"         
    elif data["Percentage"]>35:
        data["Grade"]="C+"         
    else:
        data["Grade"]="F"   
        
    return data

# %%
data.head()
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
# 2      Ayaan    Jadhav       90       75         88           84
# 3      Arjun      More       76       89         91           78
# 4    Reyansh     Joshi       82       80         84           85

# %%
data2=data.apply(Calculate_Result,axis=1)

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks  Percentage Grade
# 0           345       86.25    A+
# 1           343       85.75    A+
# 2           337       84.25    A+
# ...

# %%
data.apply(Calculate_Result,axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23176\2890406966.py in <module>
# ----> 1 data.apply(Calculate_Result,axis=0)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ...

# %%
data2.head()
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 0      Aarav     Patil       85       78         90           92          345
# 1     Vihaan  Deshmukh       88       81         85           89          343
# 2      Ayaan    Jadhav       90       75         88           84          337
# 3      Arjun      More       76       89         91           78          334
# 4    Reyansh     Joshi       82       80         84           85          331
#
#    Percentage Grade
# 0       86.25    A+
# 1       85.75    A+
# 2       84.25    A+
# 3       83.50    A+
# 4       82.75    A+

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks  Percentage Grade
# 0           345       86.25    A+
# 1           343       85.75    A+
# 2           337       84.25    A+
# ...

# %%
len(data["Last Name"])
# Out:
# 65

# %%
data2["Last Name Length"]=data2["Last Name"].apply(len)

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks  Percentage Grade  Last Name Length
# 0           345       86.25    A+                 5
# 1           343       85.75    A+                 8
# ...

# %%
data2[[ 'Last Name',
       'Last Name Length']]
# Out:
#    Last Name  Last Name Length
# 0      Patil                 5
# 1   Deshmukh                 8
# 2     Jadhav                 6
# 3       More                 4
# 4      Joshi                 5
# ..       ...               ...
# 60    Dhumal                 6
# 61   Khedkar                 7
# 62     Patil                 5
# 63     Kadam                 5
# 64    Bhagat                 6
#
# [65 rows x 2 columns]

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks  Percentage Grade  Last Name Length
# 0           345       86.25    A+                 5
# 1           343       85.75    A+                 8
# ...

# %%
data.head()
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
# 2      Ayaan    Jadhav       90       75         88           84
# 3      Arjun      More       76       89         91           78
# 4    Reyansh     Joshi       82       80         84           85

# %%
data["T2"]=data[["English","Physics","Chemistry","Mathematics"]].apply(sum,axis=1)

# %%
data["Min Value"]=data[["English","Physics","Chemistry","Mathematics"]].apply(min,axis=1)

# %%
data
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Min Value  \
# 0       Aarav     Patil       85       78         90           92         78
# 1      Vihaan  Deshmukh       88       81         85           89         81
# 2       Ayaan    Jadhav       90       75         88           84         75
# 3       Arjun      More       76       89         91           78         76
# 4     Reyansh     Joshi       82       80         84           85         80
# ..        ...       ...      ...      ...        ...          ...        ...
# 60      Tarun    Dhumal       82       87         81           85         81
# 61      Arnav   Khedkar       85       90         78           89         78
# 62      Payal     Patil       89       76         87           91         76
# 63      Rahul     Kadam       81       83         84           90         81
# 64        Jay    Bhagat       90       77         65           88         65
#
#      T2
# 0   345
# 1   343
# 2   337
# ...

# %%
# Inplace mean we can use aggregate function

# %%
data[["English","Physics","Chemistry","Mathematics"]].apply(sum,axis=0)
# Out:
# English        5536
# Physics        5328
# Chemistry      5501
# Mathematics    5717
# dtype: int64

# %%
# Reshape and transform data

# %%
# pivot 

# Syntax:
# DataFrame.pivot(index=None, columns=None, values=None)

# index: The column(s) to set as the new index of the DataFrame.
# columns: The column whose unique values will become the new columns.
# values: The column(s) to populate the values in the reshaped DataFrame.

# Notes:
# The pivot() method expects the data should be unique. If you have duplicate entries, you will get a ValueError.
# In that case, consider using pivot_table().

# %%
data3=pd.read_excel(r"D:\Minskole Batch\Python\Reshape Transform data.xlsx",sheet_name="Unique")

# %%
data4=pd.read_excel(r"D:\Minskole Batch\Python\Reshape Transform data.xlsx",sheet_name="Duplicate")

# %%
data3
# Out:
#    First Name Last Name      Subject  Marks
# 0       Aarav     Patil      English     85
# 1      Vihaan  Deshmukh      English     88
# 2       Ayaan    Jadhav      English     90
# 3       Arjun      More      English     76
# 4     Reyansh     Joshi      English     82
# 5       Aarav     Patil      Physics     78
# 6      Vihaan  Deshmukh      Physics     81
# 7       Ayaan    Jadhav      Physics     75
# 8       Arjun      More      Physics     89
# 9     Reyansh     Joshi      Physics     80
# 10      Aarav     Patil    Chemistry     90
# 11     Vihaan  Deshmukh    Chemistry     85
# 12      Ayaan    Jadhav    Chemistry     88
# 13      Arjun      More    Chemistry     91
# 14    Reyansh     Joshi    Chemistry     84
# 15      Aarav     Patil  Mathematics     92
# 16     Vihaan  Deshmukh  Mathematics     89
# 17      Ayaan    Jadhav  Mathematics     84
# 18      Arjun      More  Mathematics     78
# 19    Reyansh     Joshi  Mathematics     85

# %%
data3.sort_values(by=["First Name","Last Name"])
# Out:
#    First Name Last Name      Subject  Marks
# 0       Aarav     Patil      English     85
# 5       Aarav     Patil      Physics     78
# 10      Aarav     Patil    Chemistry     90
# 15      Aarav     Patil  Mathematics     92
# 3       Arjun      More      English     76
# 8       Arjun      More      Physics     89
# 13      Arjun      More    Chemistry     91
# 18      Arjun      More  Mathematics     78
# 2       Ayaan    Jadhav      English     90
# 7       Ayaan    Jadhav      Physics     75
# 12      Ayaan    Jadhav    Chemistry     88
# 17      Ayaan    Jadhav  Mathematics     84
# 4     Reyansh     Joshi      English     82
# 9     Reyansh     Joshi      Physics     80
# 14    Reyansh     Joshi    Chemistry     84
# 19    Reyansh     Joshi  Mathematics     85
# 1      Vihaan  Deshmukh      English     88
# 6      Vihaan  Deshmukh      Physics     81
# 11     Vihaan  Deshmukh    Chemistry     85
# 16     Vihaan  Deshmukh  Mathematics     89

# %%
data3["Subject"].unique()
# Out:
# array(['English', 'Physics', 'Chemistry', 'Mathematics'], dtype=object)

# %%
data3.pivot(index=["First Name","Last Name"],columns="Subject",values="Marks")
# Out:
# Subject               Chemistry  English  Mathematics  Physics
# First Name Last Name
# Aarav      Patil             90       85           92       78
# Arjun      More              91       76           78       89
# Ayaan      Jadhav            88       90           84       75
# Reyansh    Joshi             84       82           85       80
# Vihaan     Deshmukh          85       88           89       81

# %%
data33=data3.pivot(index=["First Name","Last Name"],columns="Subject",values="Marks").reset_index()

# %%
data33
# Out:
# Subject First Name Last Name  Chemistry  English  Mathematics  Physics
# 0            Aarav     Patil         90       85           92       78
# 1            Arjun      More         91       76           78       89
# 2            Ayaan    Jadhav         88       90           84       75
# 3          Reyansh     Joshi         84       82           85       80
# 4           Vihaan  Deshmukh         85       88           89       81

# %%
data4
# Out:
#    First Name Last Name      Subject  Marks
# 0       Aarav     Patil      English     85
# 1      Vihaan  Deshmukh      English     88
# 2       Ayaan    Jadhav      English     90
# 3       Arjun      More      English     76
# 4     Reyansh     Joshi      English     82
# 5       Aarav     Patil      Physics     78
# 6      Vihaan  Deshmukh      Physics     81
# 7       Ayaan    Jadhav      Physics     75
# 8       Arjun      More      Physics     89
# 9     Reyansh     Joshi      Physics     80
# 10      Aarav     Patil    Chemistry     90
# 11     Vihaan  Deshmukh    Chemistry     85
# 12      Ayaan    Jadhav    Chemistry     88
# 13      Arjun      More    Chemistry     91
# 14    Reyansh     Joshi    Chemistry     84
# 15      Aarav     Patil  Mathematics     92
# 16     Vihaan  Deshmukh  Mathematics     89
# 17      Ayaan    Jadhav  Mathematics     84
# 18      Arjun      More  Mathematics     78
# 19    Reyansh     Joshi  Mathematics     85
# ...

# %%
data4.pivot(index=["First Name","Last Name"],columns="Subject",values="Marks").reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23176\3859960969.py in <module>
# ----> 1 data4.pivot(index=["First Name","Last Name"],columns="Subject",values="Marks").reset_index()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in pivot(self, index, columns, values)
#    7791         from pandas.core.reshape.pivot import pivot
#    7792
# -> 7793         return pivot(self, index=index, columns=columns, values=values)
#    7794
#    7795     _shared_docs[
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py in pivot(data, index, columns, values)
#     515         else:
#     516             indexed = data._constructor_sliced(data[values]._values, index=multiindex)
# --> 517     return indexed.unstack(columns_listlike)
#     518
#     519
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in unstack(self, level, fill_value)
# ...
