# %%
import pandas as pd

# %%
# # Rename 
# # Syntax
# 1)Row labelled
#  dataframe_name.rename(index         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Row         Old value : New value,

# 2)Columns labelled
#  dataframe_name.rename(columns         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Column         Old value : New value,

# %%
# # Drop # Syntax
# # 1) Drop record (row)
# dataframe_name.drop([row_index], inplace= True/False) # By default axis=0

# # 2) Drop column
# dataframe_name.drop([column_name], axis=1, inplace= True/False)

# %%
# Change column datatype /Typecasting
# Syntax
# dataframe/column.astype(new_datatype)

# %%
# Export data to excel/csv
#1) Excel file: 
#               DataFrame_name.to_excel(r"path/filename.xlsx",index=False/True)
#2) CSV file: 
#               DataFrame_name.to_csv(r"path/filename.csv",index=False/True)

# %%
data=pd.read_excel(r"D:\Minskole Batch\Python\Input data.xlsx")

# %%
data["Name"]=data["First Name"]+" "+data["Last Name"]

# %%
data
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#                Name
# 0       Aarav Patil
# 1   Vihaan Deshmukh
# 2      Ayaan Jadhav
# 3        Arjun More
# 4     Reyansh Joshi
# ..              ...
# 60     Tarun Dhumal
# 61    Arnav Khedkar
# 62      Payal Patil
# 63      Rahul Kadam
# 64       Jay Bhagat
#
# [65 rows x 7 columns]

# %%
data2=data.rename(columns={"Name":"Full Name"})

# %%
data
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#                Name
# 0       Aarav Patil
# 1   Vihaan Deshmukh
# 2      Ayaan Jadhav
# 3        Arjun More
# 4     Reyansh Joshi
# ..              ...
# 60     Tarun Dhumal
# 61    Arnav Khedkar
# 62      Payal Patil
# 63      Rahul Kadam
# 64       Jay Bhagat
#
# [65 rows x 7 columns]

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#           Full Name
# 0       Aarav Patil
# 1   Vihaan Deshmukh
# 2      Ayaan Jadhav
# 3        Arjun More
# 4     Reyansh Joshi
# ..              ...
# 60     Tarun Dhumal
# 61    Arnav Khedkar
# 62      Payal Patil
# 63      Rahul Kadam
# 64       Jay Bhagat
#
# [65 rows x 7 columns]

# %%
data.rename(columns={"Name":"Full Name"},inplace=True)

# %%
data.head(5)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
# 2      Ayaan    Jadhav       90       75         88           84
# 3      Arjun      More       76       89         91           78
# 4    Reyansh     Joshi       82       80         84           85
#
#          Full Name
# 0      Aarav Patil
# 1  Vihaan Deshmukh
# 2     Ayaan Jadhav
# 3       Arjun More
# 4    Reyansh Joshi

# %%
# Remove records/row from data

# %%
data.drop(1) # axis=0
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# 5      Vivaan      Nair       87       83         79           90
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#         Full Name
# 0     Aarav Patil
# 2    Ayaan Jadhav
# 3      Arjun More
# 4   Reyansh Joshi
# 5     Vivaan Nair
# ..            ...
# 60   Tarun Dhumal
# 61  Arnav Khedkar
# 62    Payal Patil
# 63    Rahul Kadam
# 64     Jay Bhagat
#
# [64 rows x 7 columns]

# %%
data.drop(1,axis=0)
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# 5      Vivaan      Nair       87       83         79           90
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#         Full Name
# 0     Aarav Patil
# 2    Ayaan Jadhav
# 3      Arjun More
# 4   Reyansh Joshi
# 5     Vivaan Nair
# ..            ...
# 60   Tarun Dhumal
# 61  Arnav Khedkar
# 62    Payal Patil
# 63    Rahul Kadam
# 64     Jay Bhagat
#
# [64 rows x 7 columns]

# %%
data.drop([2,3,4],axis=0,inplace=True)

# %%
b=list(range(10,51))

# %%
data.drop(b,axis=0)
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav        Patil       85       78         90           92
# 1      Vihaan     Deshmukh       88       81         85           89
# 5      Vivaan         Nair       87       83         79           90
# 6      Aditya        Pawar       92       88         76           91
# 7       Rohan  Suryavanshi       78       82         90           86
# 8       Krish      Bhosale       80       85         83           89
# 9     Samarth       Shinde       89       79         87           88
# 51      Disha       Chavan       86       83         80           89
# 52     Shreya     Dandekar       89       75         88           90
# 53      Aditi       Rajput       90       88         82           87
# 54    Radhika     Ghorpade       83       79         91           88
# 55     Nikhil     Patankar       87       80         89           84
# 56      Aarvi     Bhandari       90       81         85           91
# 57     Raghav     Khedekar       79       86         82           90
# 58      Sneha      Gokhale       88       84         90           86
# 59      Pooja       Mhatre       84       79         88           92
# 60      Tarun       Dhumal       82       87         81           85
# 61      Arnav      Khedkar       85       90         78           89
# 62      Payal        Patil       89       76         87           91
# 63      Rahul        Kadam       81       83         84           90
# 64        Jay       Bhagat       90       77         65           88
#
#             Full Name
# 0         Aarav Patil
# 1     Vihaan Deshmukh
# 5         Vivaan Nair
# 6        Aditya Pawar
# 7   Rohan Suryavanshi
# 8       Krish Bhosale
# 9      Samarth Shinde
# 51       Disha Chavan
# 52    Shreya Dandekar
# 53       Aditi Rajput
# 54   Radhika Ghorpade
# 55    Nikhil Patankar
# 56     Aarvi Bhandari
# 57    Raghav Khedekar
# 58      Sneha Gokhale
# 59       Pooja Mhatre
# 60       Tarun Dhumal
# 61      Arnav Khedkar
# 62        Payal Patil
# 63        Rahul Kadam
# 64         Jay Bhagat

# %%
data
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav        Patil       85       78         90           92
# 1      Vihaan     Deshmukh       88       81         85           89
# 5      Vivaan         Nair       87       83         79           90
# 6      Aditya        Pawar       92       88         76           91
# 7       Rohan  Suryavanshi       78       82         90           86
# ..        ...          ...      ...      ...        ...          ...
# 60      Tarun       Dhumal       82       87         81           85
# 61      Arnav      Khedkar       85       90         78           89
# 62      Payal        Patil       89       76         87           91
# 63      Rahul        Kadam       81       83         84           90
# 64        Jay       Bhagat       90       77         65           88
#
#             Full Name
# 0         Aarav Patil
# 1     Vihaan Deshmukh
# 5         Vivaan Nair
# 6        Aditya Pawar
# 7   Rohan Suryavanshi
# ..                ...
# 60       Tarun Dhumal
# 61      Arnav Khedkar
# 62        Payal Patil
# 63        Rahul Kadam
# 64         Jay Bhagat
#
# [62 rows x 7 columns]

# %%
# Delete column from dataframe

# %%
data.head(2)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
#
#          Full Name
# 0      Aarav Patil
# 1  Vihaan Deshmukh

# %%
data.drop("First Name")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10612\381553510.py in <module>
# ----> 1 data.drop("First Name")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['First Name'] not found in axis"

# %%
data.drop("First Name",axis=1)
# Out:
#       Last Name  English  Physics  Chemistry  Mathematics          Full Name
# 0         Patil       85       78         90           92        Aarav Patil
# 1      Deshmukh       88       81         85           89    Vihaan Deshmukh
# 5          Nair       87       83         79           90        Vivaan Nair
# 6         Pawar       92       88         76           91       Aditya Pawar
# 7   Suryavanshi       78       82         90           86  Rohan Suryavanshi
# ..          ...      ...      ...        ...          ...                ...
# 60       Dhumal       82       87         81           85       Tarun Dhumal
# 61      Khedkar       85       90         78           89      Arnav Khedkar
# 62        Patil       89       76         87           91        Payal Patil
# 63        Kadam       81       83         84           90        Rahul Kadam
# 64       Bhagat       90       77         65           88         Jay Bhagat
#
# [62 rows x 6 columns]

# %%
# # If you want to delete
# rows use axis=0 ( By default axis value is 0 . Not mandadtory to define)
# Column use axis=1

# %%
data.drop(["First Name","Last Name"],axis=1,inplace=True)

# %%
data
# Out:
#     English  Physics  Chemistry  Mathematics          Full Name
# 0        85       78         90           92        Aarav Patil
# 1        88       81         85           89    Vihaan Deshmukh
# 5        87       83         79           90        Vivaan Nair
# 6        92       88         76           91       Aditya Pawar
# 7        78       82         90           86  Rohan Suryavanshi
# ..      ...      ...        ...          ...                ...
# 60       82       87         81           85       Tarun Dhumal
# 61       85       90         78           89      Arnav Khedkar
# 62       89       76         87           91        Payal Patil
# 63       81       83         84           90        Rahul Kadam
# 64       90       77         65           88         Jay Bhagat
#
# [62 rows x 5 columns]

# %%
# Change column datatype /Typecasting
# Syntax
# dataframe/column.astype(new_datatype)

# %%
data=data[[ 'Full Name','English', 'Physics', 'Chemistry', 'Mathematics']]

# %%
data.dtypes
# Out:
# Full Name      object
# English         int64
# Physics         int64
# Chemistry       int64
# Mathematics     int64
# dtype: object

# %%
data["Mathematics"].dtypes
# Out:
# dtype('int64')

# %%
data=data.astype(str)

# %%
data.dtypes
# Out:
# Full Name      object
# English        object
# Physics        object
# Chemistry      object
# Mathematics    object
# dtype: object

# %%
data
# Out:
#             Full Name English Physics Chemistry Mathematics
# 0         Aarav Patil      85      78        90          92
# 1     Vihaan Deshmukh      88      81        85          89
# 5         Vivaan Nair      87      83        79          90
# 6        Aditya Pawar      92      88        76          91
# 7   Rohan Suryavanshi      78      82        90          86
# ..                ...     ...     ...       ...         ...
# 60       Tarun Dhumal      82      87        81          85
# 61      Arnav Khedkar      85      90        78          89
# 62        Payal Patil      89      76        87          91
# 63        Rahul Kadam      81      83        84          90
# 64         Jay Bhagat      90      77        65          88
#
# [62 rows x 5 columns]

# %%
data["Total Marks"]=data['English']+data[ 'Physics']+data[ 'Chemistry']+data[ 'Mathematics']

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics Total Marks
# 0         Aarav Patil       85       78         90           92    85789092
# 1     Vihaan Deshmukh       88       81         85           89    88818589
# 5         Vivaan Nair       87       83         79           90    87837990
# 6        Aditya Pawar       92       88         76           91    92887691
# 7   Rohan Suryavanshi       78       82         90           86    78829086
# ..                ...      ...      ...        ...          ...         ...
# 60       Tarun Dhumal       82       87         81           85    82878185
# 61      Arnav Khedkar       85       90         78           89    85907889
# 62        Payal Patil       89       76         87           91    89768791
# 63        Rahul Kadam       81       83         84           90    81838490
# 64         Jay Bhagat       90       77         65           88    90776588
#
# [62 rows x 6 columns]

# %%
data['English']=data['English'].astype(int)

# %%
data[ 'Physics']=data[ 'Physics'].astype(int)

# %%
data[ 'Chemistry']=data[ 'Chemistry'].astype(int)

# %%
data[ 'Mathematics']=data[ 'Mathematics'].astype(int)

# %%
data["Total Marks"]=data['English']+data[ 'Physics']+data[ 'Chemistry']+data[ 'Mathematics']

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0         Aarav Patil       85       78         90           92          345
# 1     Vihaan Deshmukh       88       81         85           89          343
# 5         Vivaan Nair       87       83         79           90          339
# 6        Aditya Pawar       92       88         76           91          347
# 7   Rohan Suryavanshi       78       82         90           86          336
# ..                ...      ...      ...        ...          ...          ...
# 60       Tarun Dhumal       82       87         81           85          335
# 61      Arnav Khedkar       85       90         78           89          342
# 62        Payal Patil       89       76         87           91          343
# 63        Rahul Kadam       81       83         84           90          338
# 64         Jay Bhagat       90       77         65           88          320
#
# [62 rows x 6 columns]

# %%
data["Percentage"]=(data["Total Marks"]/400)*100  # Recived marks/Total marks *100

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 0         Aarav Patil       85       78         90           92          345
# 1     Vihaan Deshmukh       88       81         85           89          343
# 5         Vivaan Nair       87       83         79           90          339
# 6        Aditya Pawar       92       88         76           91          347
# 7   Rohan Suryavanshi       78       82         90           86          336
# ..                ...      ...      ...        ...          ...          ...
# 60       Tarun Dhumal       82       87         81           85          335
# 61      Arnav Khedkar       85       90         78           89          342
# 62        Payal Patil       89       76         87           91          343
# 63        Rahul Kadam       81       83         84           90          338
# 64         Jay Bhagat       90       77         65           88          320
#
#     Percentage
# 0        86.25
# 1        85.75
# 5        84.75
# 6        86.75
# 7        84.00
# ..         ...
# 60       83.75
# 61       85.50
# 62       85.75
# 63       84.50
# 64       80.00
#
# [62 rows x 7 columns]

# %%
data
# Out:
#             Full Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 0         Aarav Patil       85       78         90           92          345
# 1     Vihaan Deshmukh       88       81         85           89          343
# 5         Vivaan Nair       87       83         79           90          339
# 6        Aditya Pawar       92       88         76           91          347
# 7   Rohan Suryavanshi       78       82         90           86          336
# ..                ...      ...      ...        ...          ...          ...
# 60       Tarun Dhumal       82       87         81           85          335
# 61      Arnav Khedkar       85       90         78           89          342
# 62        Payal Patil       89       76         87           91          343
# 63        Rahul Kadam       81       83         84           90          338
# 64         Jay Bhagat       90       77         65           88          320
#
#     Percentage
# 0        86.25
# 1        85.75
# 5        84.75
# 6        86.75
# 7        84.00
# ..         ...
# 60       83.75
# 61       85.50
# 62       85.75
# 63       84.50
# 64       80.00
#
# [62 rows x 7 columns]

# %%
data.to_excel(r"D:\Minskole Batch\Python\Export\Report.xlsx")

# %%
data.to_excel(r"D:\Minskole Batch\Python\Export\Report2.xlsx",index=False)

# %%
data.to_csv(r"D:\Minskole Batch\Python\Export\Report_csv.csv")

# %%
data.to_csv(r"D:\Minskole Batch\Python\Export\Report_csv2.csv",index=False)
